# %%
# pandas is a library and it has the functions related to databases
import pandas as pd

# %%
# we are importing the data from .csv file and store it in a variable called dataset
dataset= pd.read_csv("Salary_Data.csv")

# %%
dataset
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
# separating the dependent and independent variables in dataset
independent= dataset[["YearsExperience"]]

# %%
dependent= dataset[["Salary"]]

# %%
# We have a method called test_train_split in model_selection class of sklearn package,
#which helps us to split the train and test datas of the independent and dependent variables
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(independent, dependent, test_size=0.30, random_state=0)

# %%
# assigned an object for the LinearRegrssion() class in linear_model and
# .fit create the model with the given training data set(y=mx+c -> SLR)
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# coef_ is equal to m(slope) in y=mx+c. We are valdating the weight of the model and intercept of the model
#intercept_ is equal to c which we call as bias
weight = regressor.coef_
weight
# Out:
# array([[9360.26128619]])

# %%
bias = regressor.intercept_
bias
# Out:
# array([26777.3913412])

# %%
# Now we are going to test the model by passing the test data to the created model
y_pred=regressor.predict(x_test)

# %%
#r2_score is an error validation method which validates our models output with the actual output of the test data we have
# If the r2_score is near to 1 then the model is efficient
from sklearn.metrics import r2_score
r_score=r2_score(y_test, y_pred)
r_score
# Out:
# 0.9740993407213511

# %%
# pickle is imported to dump and load our model(saving the model) and use it in future with realtime data
import pickle
filename = "finalized_model_linear.sav"

# %%
# now our model named regressor is stored in the filename  "finalized_model_linear.sav"
pickle.dump(regressor, open(filename, 'wb'))

# %%
# Now er are loading the saved model and give the yearsofexperience as 15 (use [[]]) for input
loaded_model=pickle.load(open("finalized_model_linear.sav","rb"))
result=loaded_model.predict([[15]])
# Out:
# C:\Anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[167181.3106341]])
