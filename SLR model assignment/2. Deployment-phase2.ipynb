# %%
#Here we have our model loaded and checks the data for yearsofexperience as 0
# We have our data in.csv file starting fro 1.1 only, so for 0 years it will retur the bias as output since coeff_ will be multiplied with 0
import pickle
loaded_model=pickle.load(open("finalized_model_linear.sav","rb"))
result=loaded_model.predict([[0]])
# Out:
# C:\Anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[26777.3913412]])
