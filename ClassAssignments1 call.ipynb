# %%
from ClassAssignments1 import subfieldsInAI, multipleFunctions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from ClassAssignments1 import subfieldsInAI, multipleFunctions
#
# File D:\Hope AI\Python\ClassAssignments1.py:20
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 1,
#       6    "id": "808af3cb-cd06-41a9-a641-2eedbe83f7c4",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "class subfieldsInAI():\n",
#      11     "    subfield_list = [\"Machine Learning\",\"Neural Networks\", \"Vision\", \"Robotics\", \"Speech Processing\", \"Natural Language Processing\"]\n",
#      12     "    def subfields():\n",
#      13     "        print(\"Sub-fields in AI are:\")\n",
#      14     "        for field in subfield_list:\n",
#      15     "            print(field)"
#      16    ]
#      17   },
# ...

# %%
subfieldsInAI.subfields()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 subfieldsInAI.subfields
#
# NameError: name 'subfieldsInAI' is not defined

# %%
multipleFunctions.oddEven()
