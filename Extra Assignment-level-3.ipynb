# %%
i=int(input("Value:"))
if (i==10):
    print("CORRECT")
# Out:
# Value: 10
# CORRECT

# %%
pswd=input("Enter the Password:")
if pswd=="Sank":
    print("Your pswd is Correct")
# Out:
# Enter the Password: Sank
# Your pswd is Correct

# %%
age=int(input("Value:"))
if age<18:
    print("Children")
elif age<40:
    print("Adult")
elif age<60:
    print("Citizen")
else:
    print("senior citizen")
# Out:
# Value: 24
# Adult

# %%
num = int(input("Enter any number:"))
if num>0:
    print("Positive")
elif num==0:
    print("Value is 0, enter valid number")
else:
    print("negative")
# Out:
# Enter any number: 1
# Positive

# %%
num = int(input("Enter any number:"))
if num%5==0:
    print("Number is divisible by 5")
else:
    print("Number is not divisible by 5")
# Out:
# Enter any number: 10
# Number is divisible by 5
