# %%
from Assignmentclass import multipleFunctions

# %%
multipleFunctions.oddEven()
# Out:
# Enter the number: 23
# Odd number
# 'Odd number'

# %%
multipleFunctions.subfields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
multipleFunctions.marriageAge()
# Out:
# Your Gender: male
# Your Age: 23
# ELIGIBLE

# %%
marksList=[80,75,89,98,100]
multipleFunctions.percentage(marksList)
# Out:
# Total:  442
# Percentage: 88.4000000000000

# %%
multipleFunctions.triangle_area(2,3)
# Out:
# Area of triangle:  3.0

# %%
multipleFunctions.triangle_perimeter(2,3,4)
# Out:
# Perimeter of triangle:  9
