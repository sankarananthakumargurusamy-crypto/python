# %%
age=int(input("Enter Age:"))
if(age==18):
    print("Adult")
# Out:
# Enter Age: 18
# Adult

# %%
if (age<18):
    print("Children")
else:
    print("Adult")
# Out:
# Adult

# %%
if (age<18):
    print("Children")
elif(age<35):
    print("Adult")
elif(age<59):
    print("Citizen")
else:
    print("Senior Citizen")
# Out:
# Adult

# %%
lists=[23,45,67,34,89]
for temp in lists:
    print(temp)
# Out:
# 23
# 45
# 67
# 34
# 89

# %%
for age in lists:
    if (age<18):
        print("Children")
    elif(age<35):
        print("Adult")
    elif(age<59):
        print("Citizen")
    else:
        print("Senior Citizen")
# Out:
# Adult
# Citizen
# Senior Citizen
# Adult
# Senior Citizen
